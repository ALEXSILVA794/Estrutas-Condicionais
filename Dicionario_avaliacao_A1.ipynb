# %% [markdown]
# <a href="https://colab.research.google.com/github/ALEXSILVA794/Avaliacao-A1-Tecnicas-de-Desenvolvimento-de-Algotitimos/blob/main/Dicionario_avaliacao_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistema simples de cadastro de produtos usando dicionários

produtos = {}  # dicionário vazio

print("Cadastro de Produtos")
print("Digite 'sair' no nome do produto para encerrar.\n")

while True:
    nome = input("Nome do produto: ")

    if nome.lower() == "sair":
        break

    preco = input("Preço do produto: ")

    # Armazena no dicionário
    produtos[nome] = preco

print("\nProdutos cadastrados:")
for nome, preco in produtos.items():
    print(f"- {nome}: R$ {preco}")
# Out:
# Cadastro de Produtos
# Digite 'sair' no nome do produto para encerrar.
#
# Nome do produto: Carro
# Preço do produto: 20000
# Nome do produto: Fiat
# Preço do produto: 100
# Nome do produto: sair
#
# Produtos cadastrados:
# - Carro: R$ 20000
# - Fiat: R$ 100
